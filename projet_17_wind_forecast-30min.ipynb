# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split

from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline

from sklearn.metrics import mean_absolute_error, r2_score, mean_squared_error, mean_absolute_percentage_error

import time
import xgboost as xgb

# %%
# 1. Chargement et Tri
df = pd.read_parquet('data/processed_windspeed.parquet', engine='fastparquet')
df['horodatage_référence'] = pd.to_datetime(df['horodatage_référence'], dayfirst=True)
df = df.sort_values('horodatage_référence').reset_index(drop=True)

# 2. Gestion des NaN (Interpolation linéaire : relie les points logiquement en comblant les trous)
# On ne traite que les colonnes numériques
cols_num = df.select_dtypes(include=[np.number]).columns
df[cols_num] = df[cols_num].interpolate(method='linear').bfill()

# 3. Feature Engineering (Heure, Mois et Retards temporels)
df['hour'] = df['horodatage_référence'].dt.hour
df['month'] = df['horodatage_référence'].dt.month

# On crée des lags : le vent à T-10min et T-20min
# ? Les lags permettent d'éviter pour les premières lignes des erreurs car le programme ne trouve pas de données avant dans le temps
target = 'vitesse_vent_moyenne_10min_kmh'

### EDIT
df['target_30min'] = df[target].shift(-3)

df['vent_10min_avant'] = df[target].shift(1) # ? décalage des données de la colonne vers 1 en bas
df['vent_20min_avant'] = df[target].shift(2) # ? décalage des données de la colonne vers 2 en bas
df['vent_30min_avant'] = df[target].shift(3) # ? décalage des données de la colonne vers 3 en bas
df['vent_40min_avant'] = df[target].shift(4) # ? décalage des données de la colonne vers 4 en bas
df['vent_50min_avant'] = df[target].shift(5) # ? décalage des données de la colonne vers 5 en bas
df['vent_60min_avant'] = df[target].shift(6) # ? décalage des données de la colonne vers 6 en bas

df['vent_tendance_1h'] = df[target] - df['vent_60min_avant']

df['pression_atmospherique_6h'] = df['pression_barométrique_qfe_valeur_instantanée'].shift(36) # ? décalage des données de la colonne vers 36 en bas
df['pression_tendance_6h'] = df['pression_barométrique_qfe_valeur_instantanée'] - df['pression_atmospherique_6h']

# On supprime les lignes du début devenues NaN à cause du décalage (shift)
#df = df.dropna(subset=['vent_10min_avant', 
#                       'vent_20min_avant', 
#                       'vent_30min_avant', 
#                       'vent_40min_avant', 
#                       'vent_50min_avant', 
#                       'vent_60min_avant',
#                       'pression_tendance_6h',
#                      'target_30min'])






# Supprimer toutes les lignes avec NaN dans les features utilisées
features_to_check = [
    'vent_10min_avant', 
    'vent_20min_avant',
    'vent_30min_avant', 
    'vent_40min_avant', 
    'vent_50min_avant', 
    'vent_60min_avant',
    'vent_tendance_1h',
    'direction_du_vent_moyenne_10min',
    'hour', 
    'month',
    'pression_tendance_6h',
    'humidité_relative_air_2m_valeur_instantanée',
    'précipitations_somme_10min',
    'température_air_2m_valeur_instantanée',
    'rafale_3s_maximum_kmh'
]
df = df.dropna(subset=features_to_check)

# %% [raw]
# print(df['pression_barométrique_qfe_valeur_instantanée'], df['pression_atmospherique_6h'], df['pression_tendance_6h'])

# %% [markdown]
# ### Choix des variables + Split

# %%
# Choix des variables explicatives (Features)
# On évite de mettre les autres colonnes de vent "moyenne" qui donneraient la réponse au modèle
features = [
    'vent_10min_avant', 
    'vent_20min_avant',
    'vent_30min_avant', 
    'vent_40min_avant', 
    'vent_50min_avant', 
    'vent_60min_avant',
    'vent_tendance_1h',
    'direction_du_vent_moyenne_10min',
    'hour', 
    'month',
    'pression_tendance_6h',
    'humidité_relative_air_2m_valeur_instantanée',
    'précipitations_somme_10min',
    'température_air_2m_valeur_instantanée',
    'rafale_3s_maximum_kmh'
]

# On s'assure que les colonnes existent avant de split
features = [f for f in features if f in df.columns]

# Split chronologique (le passé sert d'entrainement)
split_idx = int(len(df) * 0.8) # longueur du df - 80% sont gardés pour le train et 20% pour le test
train_df = df.iloc[:split_idx] # on prend tout ce qui avant l'index
test_df = df.iloc[split_idx:] # on prend tout ce qui a après l'index


### Old
#X_train, y_train = train_df[features], train_df[target]
#X_test, y_test = test_df[features], test_df[target]

# On prépare les données dans le format "DMatrix" (optimisé GPU)
#dtrain = xgb.DMatrix(X_train, label=y_train, enable_categorical=True)
#dtest = xgb.DMatrix(X_test, label=y_test, enable_categorical=True)


### Edit
X_train, y_train = train_df[features], train_df['target_30min']
test_df_shifted = test_df[features].shift(10).dropna()
y_test = test_df['target_30min'].shift(10).iloc[:len(test_df_shifted)].dropna()
X_test = test_df_shifted.loc[y_test.index]

# On prépare les données dans le format "DMatrix" (optimisé GPU)
dtrain = xgb.DMatrix(X_train, label=y_train, enable_categorical=True)
dtest = xgb.DMatrix(X_test, label=y_test, enable_categorical=True)

# %% [markdown]
# ### Création du pipeline + entrainement + prédiction + résultats

# %%
# 1. Configuration du modèle pour GPU
params = {
    'max_depth': 5,
    'eta': 0.1, # = learning rate (si trop élevé = risque d'overfitting) -> défaut = 0.3
    'objective': 'reg:squarederror',
    'tree_method': 'hist',
    'device': 'cuda',
    'random_state': 42
}

evals_result = {} # Création du dictionnaire pour les graphiques

print(f"🚀 Lancement de l'entraînement GPU sur {len(X_train)} lignes...")
start_time = time.time() # on déclenche le chrono

model = xgb.train(params, 
                  dtrain, 
                  num_boost_round=200, # nombre d'arbres
                  evals=[(dtrain, 'train'), (dtest, 'test')], 
                  evals_result=evals_result,                  
                  verbose_eval=True
)

end_time = time.time()
duree = end_time - start_time # calcul du temps

print(f"✅ Terminé en {duree:.2f} secondes (soit {duree/60:.2f} minutes)")

# Prédiction
y_pred = model.predict(dtest)
y_pred_train = model.predict(dtrain)











# ÉVALUATION AVANCÉE
mae = mean_absolute_error(y_test, y_pred)
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
r2 = r2_score(y_test, y_pred)
r2_train = r2_score(y_train, y_pred_train)

mask = y_test > 0.5
mape_clean = mean_absolute_percentage_error(y_test[mask], y_pred[mask])

print(f"--- RÉSULTATS ---")
print(f"Score R² (TEST) : {r2:.4f}")
print(f"Score R² (TRAIN) : {r2_train:.4f} (Pour vérifier l'overfitting)")
print(f"Erreur moyenne (MAE) : {mae:.2f} km/h")
print(f"RMSE : {rmse:.2f} km/h")


#####################################################################################################################
# --- NOUVEAU : CALCUL DE L'ACCURACY (R²) PAR ÉTAPE ---
# On transforme le MSE stocké par XGBoost en score R2 approximatif pour le graph
train_mse = np.array(evals_result['train']['rmse'])**2
test_mse = np.array(evals_result['test']['rmse'])**2
var_y = np.var(y_test)
train_r2_history = 1 - (train_mse / np.var(y_train))
test_r2_history = 1 - (test_mse / var_y)

# Visualisations / Graphiques
plt.figure(figsize=(18, 15))

# --- GRAPHIQUE 1 : TRAIN & TEST LOSS (RMSE) ---
plt.subplot(2, 2, 1)
metric_name = 'rmse'
epochs = len(evals_result['train'][metric_name])
plt.plot(range(epochs), evals_result['train'][metric_name], label='Train Loss', color='blue')
plt.plot(range(epochs), evals_result['test'][metric_name], label='Test Loss', color='red', linestyle='--')
plt.title("Évolution du Loss (Erreur RMSE)")
plt.legend()
plt.grid(alpha=0.3)

# --- GRAPHIQUE 2 : TRAIN & TEST "ACCURACY" (R²) ZOOMÉ ---
plt.subplot(2, 2, 2)
plt.plot(range(epochs), train_r2_history, label='Train R²', color='green')
plt.plot(range(epochs), test_r2_history, label='Test R²', color='darkorange', linestyle='--')

# On cherche la valeur minimale de R2 après le 50ème arbre pour caler le bas du graphique
# Si le modèle est déjà très haut, on peut aussi forcer une valeur fixe comme 0.90 ou 0.95
valeur_min_zoom = max(0.996, np.min(test_r2_history[10:])) 
plt.ylim(valeur_min_zoom, 1.001) # On s'arrête juste au dessus de 1

plt.title("Focus sur la convergence (Score R²)")
plt.xlabel("Nombre d'arbres")
plt.ylabel("R² (Zoomé)")
plt.legend()
plt.grid(alpha=0.3, which='both') # 'both' pour voir les petites lignes de grille

# --- GRAPHIQUE 3 : DISTRIBUTION DES ERREURS ---
plt.subplot(2, 2, 3)
residus = y_test - y_pred
sns.histplot(residus, bins=100, kde=True, color='purple')
plt.axvline(x=0, color='black', linestyle='--')
plt.title("Distribution des erreurs (Résidus)")

# --- GRAPHIQUE 4 : IMPORTANCE DES VARIABLES ---
plt.subplot(2, 2, 4)
importance_dict = model.get_score(importance_type='weight')
importances = [importance_dict.get(f, 0) for f in features]
sns.barplot(x=importances, y=features, palette='viridis')
plt.title("Importance des variables")

plt.tight_layout()
plt.show()

# --- GRAPHIQUE FINAL : ZOOM TEMPOREL ---
plt.figure(figsize=(18, 6))
plt.plot(y_test.values[:300], label='Réel', color='black', alpha=0.7)
plt.plot(y_pred[:300], label='Prédit', color='orange', linestyle='--')
plt.title("Zoom 50h : Réel vs Prédit")
plt.legend()
plt.show()
# Out:
# 🚀 Lancement de l'entraînement GPU sur 909288 lignes...
# /home/alex/miniconda3/lib/python3.13/site-packages/xgboost/training.py:200: UserWarning: [16:23:24] WARNING: /__w/xgboost/xgboost/src/context.cc:53: No visible GPU is found, setting device to CPU.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/alex/miniconda3/lib/python3.13/site-packages/xgboost/training.py:200: UserWarning: [16:23:24] WARNING: /__w/xgboost/xgboost/src/context.cc:207: Device is changed from GPU to CPU as we couldn't find any available GPU on the system.
#   bst.update(dtrain, iteration=i, fobj=obj)
# [0]	train-rmse:6.48166	test-rmse:6.45008
# [1]	train-rmse:6.12896	test-rmse:6.08234
# [2]	train-rmse:5.82545	test-rmse:5.76289
# [3]	train-rmse:5.56551	test-rmse:5.49127
# [4]	train-rmse:5.34461	test-rmse:5.26125
# [5]	train-rmse:5.15588	test-rmse:5.06731
# [6]	train-rmse:4.99551	test-rmse:4.90486
# [7]	train-rmse:4.85965	test-rmse:4.76640
# [8]	train-rmse:4.74490	test-rmse:4.65155
# [9]	train-rmse:4.64842	test-rmse:4.55621
# [10]	train-rmse:4.56700	test-rmse:4.47671
# [11]	train-rmse:4.49659	test-rmse:4.40832
# [12]	train-rmse:4.43554	test-rmse:4.35221
# [13]	train-rmse:4.38353	test-rmse:4.30289
# [14]	train-rmse:4.33870	test-rmse:4.26375
# [15]	train-rmse:4.29873	test-rmse:4.23014
# [16]	train-rmse:4.26484	test-rmse:4.20188
# [17]	train-rmse:4.23637	test-rmse:4.17867
# [18]	train-rmse:4.20921	test-rmse:4.15672
# [19]	train-rmse:4.18696	test-rmse:4.13914
# [20]	train-rmse:4.16676	test-rmse:4.12276
# [21]	train-rmse:4.14977	test-rmse:4.11008
# [22]	train-rmse:4.13587	test-rmse:4.09920
# [23]	train-rmse:4.12302	test-rmse:4.09031
# [24]	train-rmse:4.11201	test-rmse:4.08283
# [25]	train-rmse:4.10288	test-rmse:4.07655
# [26]	train-rmse:4.09507	test-rmse:4.07124
# [27]	train-rmse:4.08790	test-rmse:4.06650
# [28]	train-rmse:4.08130	test-rmse:4.06204
# [29]	train-rmse:4.07564	test-rmse:4.05864
# [30]	train-rmse:4.07002	test-rmse:4.05442
# [31]	train-rmse:4.06515	test-rmse:4.05154
# [32]	train-rmse:4.06098	test-rmse:4.04923
# [33]	train-rmse:4.05593	test-rmse:4.04539
# [34]	train-rmse:4.05205	test-rmse:4.04310
# [35]	train-rmse:4.04822	test-rmse:4.04101
# [36]	train-rmse:4.04438	test-rmse:4.03830
# [37]	train-rmse:4.04081	test-rmse:4.03660
# [38]	train-rmse:4.03754	test-rmse:4.03472
# [39]	train-rmse:4.03456	test-rmse:4.03282
# [40]	train-rmse:4.03131	test-rmse:4.03116
# [41]	train-rmse:4.02843	test-rmse:4.02945
# [42]	train-rmse:4.02570	test-rmse:4.02782
# [43]	train-rmse:4.02301	test-rmse:4.02581
# [44]	train-rmse:4.02028	test-rmse:4.02430
# [45]	train-rmse:4.01748	test-rmse:4.02175
# [46]	train-rmse:4.01512	test-rmse:4.02055
# [47]	train-rmse:4.01273	test-rmse:4.01938
# [48]	train-rmse:4.01032	test-rmse:4.01821
# [49]	train-rmse:4.00842	test-rmse:4.01710
# [50]	train-rmse:4.00617	test-rmse:4.01613
# [51]	train-rmse:4.00439	test-rmse:4.01511
# [52]	train-rmse:4.00245	test-rmse:4.01417
# [53]	train-rmse:4.00085	test-rmse:4.01366
# [54]	train-rmse:3.99899	test-rmse:4.01314
# [55]	train-rmse:3.99747	test-rmse:4.01204
# [56]	train-rmse:3.99579	test-rmse:4.01112
# [57]	train-rmse:3.99439	test-rmse:4.01051
# [58]	train-rmse:3.99286	test-rmse:4.00973
# [59]	train-rmse:3.99150	test-rmse:4.00908
# [60]	train-rmse:3.98983	test-rmse:4.00817
# [61]	train-rmse:3.98791	test-rmse:4.00712
# [62]	train-rmse:3.98669	test-rmse:4.00685
# [63]	train-rmse:3.98524	test-rmse:4.00598
# [64]	train-rmse:3.98377	test-rmse:4.00572
# [65]	train-rmse:3.98207	test-rmse:4.00477
# [66]	train-rmse:3.98100	test-rmse:4.00426
# [67]	train-rmse:3.97961	test-rmse:4.00375
# [68]	train-rmse:3.97834	test-rmse:4.00322
# [69]	train-rmse:3.97702	test-rmse:4.00247
# [70]	train-rmse:3.97567	test-rmse:4.00183
# [71]	train-rmse:3.97455	test-rmse:4.00110
# [72]	train-rmse:3.97311	test-rmse:4.00041
# [73]	train-rmse:3.97179	test-rmse:3.99975
# [74]	train-rmse:3.97032	test-rmse:3.99882
# [75]	train-rmse:3.96916	test-rmse:3.99808
# [76]	train-rmse:3.96788	test-rmse:3.99753
# [77]	train-rmse:3.96651	test-rmse:3.99710
# [78]	train-rmse:3.96508	test-rmse:3.99644
# [79]	train-rmse:3.96375	test-rmse:3.99582
# [80]	train-rmse:3.96278	test-rmse:3.99542
# [81]	train-rmse:3.96159	test-rmse:3.99516
# [82]	train-rmse:3.96060	test-rmse:3.99467
# [83]	train-rmse:3.95976	test-rmse:3.99433
# [84]	train-rmse:3.95838	test-rmse:3.99369
# [85]	train-rmse:3.95706	test-rmse:3.99304
# [86]	train-rmse:3.95592	test-rmse:3.99269
# [87]	train-rmse:3.95471	test-rmse:3.99224
# [88]	train-rmse:3.95388	test-rmse:3.99214
# [89]	train-rmse:3.95304	test-rmse:3.99185
# [90]	train-rmse:3.95194	test-rmse:3.99157
# [91]	train-rmse:3.95087	test-rmse:3.99085
# [92]	train-rmse:3.94982	test-rmse:3.99042
# [93]	train-rmse:3.94870	test-rmse:3.98989
# [94]	train-rmse:3.94793	test-rmse:3.98955
# [95]	train-rmse:3.94687	test-rmse:3.98913
# [96]	train-rmse:3.94610	test-rmse:3.98879
# [97]	train-rmse:3.94510	test-rmse:3.98864
# [98]	train-rmse:3.94414	test-rmse:3.98838
# [99]	train-rmse:3.94315	test-rmse:3.98780
# [100]	train-rmse:3.94248	test-rmse:3.98749
# [101]	train-rmse:3.94191	test-rmse:3.98717
# [102]	train-rmse:3.94083	test-rmse:3.98676
# [103]	train-rmse:3.93987	test-rmse:3.98630
# [104]	train-rmse:3.93899	test-rmse:3.98588
# [105]	train-rmse:3.93805	test-rmse:3.98526
# [106]	train-rmse:3.93736	test-rmse:3.98511
# [107]	train-rmse:3.93655	test-rmse:3.98487
# [108]	train-rmse:3.93586	test-rmse:3.98448
# [109]	train-rmse:3.93529	test-rmse:3.98418
# [110]	train-rmse:3.93450	test-rmse:3.98395
# [111]	train-rmse:3.93371	test-rmse:3.98346
# [112]	train-rmse:3.93282	test-rmse:3.98321
# [113]	train-rmse:3.93213	test-rmse:3.98288
# [114]	train-rmse:3.93150	test-rmse:3.98259
# [115]	train-rmse:3.93090	test-rmse:3.98247
# [116]	train-rmse:3.93006	test-rmse:3.98223
# [117]	train-rmse:3.92926	test-rmse:3.98196
# [118]	train-rmse:3.92875	test-rmse:3.98172
# [119]	train-rmse:3.92793	test-rmse:3.98130
# [120]	train-rmse:3.92714	test-rmse:3.98129
# [121]	train-rmse:3.92676	test-rmse:3.98121
# [122]	train-rmse:3.92589	test-rmse:3.98112
# [123]	train-rmse:3.92517	test-rmse:3.98082
# [124]	train-rmse:3.92432	test-rmse:3.98036
# [125]	train-rmse:3.92354	test-rmse:3.98049
# [126]	train-rmse:3.92294	test-rmse:3.98020
# [127]	train-rmse:3.92222	test-rmse:3.97994
# [128]	train-rmse:3.92158	test-rmse:3.97963
# [129]	train-rmse:3.92109	test-rmse:3.97949
# [130]	train-rmse:3.92041	test-rmse:3.97939
# [131]	train-rmse:3.91985	test-rmse:3.97929
# [132]	train-rmse:3.91939	test-rmse:3.97917
# [133]	train-rmse:3.91859	test-rmse:3.97885
# [134]	train-rmse:3.91778	test-rmse:3.97856
# [135]	train-rmse:3.91708	test-rmse:3.97829
# [136]	train-rmse:3.91649	test-rmse:3.97803
# [137]	train-rmse:3.91596	test-rmse:3.97800
# [138]	train-rmse:3.91525	test-rmse:3.97770
# [139]	train-rmse:3.91446	test-rmse:3.97717
# [140]	train-rmse:3.91377	test-rmse:3.97677
# [141]	train-rmse:3.91306	test-rmse:3.97669
# [142]	train-rmse:3.91251	test-rmse:3.97651
# [143]	train-rmse:3.91193	test-rmse:3.97642
# [144]	train-rmse:3.91143	test-rmse:3.97633
# [145]	train-rmse:3.91077	test-rmse:3.97591
# [146]	train-rmse:3.91020	test-rmse:3.97595
# [147]	train-rmse:3.90982	test-rmse:3.97590
# [148]	train-rmse:3.90911	test-rmse:3.97569
# [149]	train-rmse:3.90860	test-rmse:3.97571
# [150]	train-rmse:3.90797	test-rmse:3.97555
# [151]	train-rmse:3.90758	test-rmse:3.97539
# [152]	train-rmse:3.90700	test-rmse:3.97532
# [153]	train-rmse:3.90643	test-rmse:3.97519
# [154]	train-rmse:3.90596	test-rmse:3.97523
# [155]	train-rmse:3.90544	test-rmse:3.97502
# [156]	train-rmse:3.90505	test-rmse:3.97480
# [157]	train-rmse:3.90448	test-rmse:3.97541
# [158]	train-rmse:3.90385	test-rmse:3.97524
# [159]	train-rmse:3.90327	test-rmse:3.97518
# [160]	train-rmse:3.90279	test-rmse:3.97512
# [161]	train-rmse:3.90247	test-rmse:3.97492
# [162]	train-rmse:3.90196	test-rmse:3.97514
# [163]	train-rmse:3.90119	test-rmse:3.97502
# [164]	train-rmse:3.90037	test-rmse:3.97459
# [165]	train-rmse:3.90001	test-rmse:3.97448
# [166]	train-rmse:3.89958	test-rmse:3.97425
# [167]	train-rmse:3.89911	test-rmse:3.97411
# [168]	train-rmse:3.89862	test-rmse:3.97445
# [169]	train-rmse:3.89830	test-rmse:3.97439
# [170]	train-rmse:3.89799	test-rmse:3.97406
# [171]	train-rmse:3.89753	test-rmse:3.97384
# [172]	train-rmse:3.89710	test-rmse:3.97403
# [173]	train-rmse:3.89664	test-rmse:3.97385
# [174]	train-rmse:3.89620	test-rmse:3.97365
# [175]	train-rmse:3.89561	test-rmse:3.97349
# [176]	train-rmse:3.89527	test-rmse:3.97348
# [177]	train-rmse:3.89470	test-rmse:3.97316
# [178]	train-rmse:3.89421	test-rmse:3.97311
# [179]	train-rmse:3.89374	test-rmse:3.97296
# [180]	train-rmse:3.89341	test-rmse:3.97274
# [181]	train-rmse:3.89300	test-rmse:3.97261
# [182]	train-rmse:3.89247	test-rmse:3.97272
# [183]	train-rmse:3.89204	test-rmse:3.97312
# [184]	train-rmse:3.89157	test-rmse:3.97324
# [185]	train-rmse:3.89125	test-rmse:3.97316
# [186]	train-rmse:3.89081	test-rmse:3.97297
# [187]	train-rmse:3.89043	test-rmse:3.97281
# [188]	train-rmse:3.89007	test-rmse:3.97290
# [189]	train-rmse:3.88947	test-rmse:3.97275
# [190]	train-rmse:3.88899	test-rmse:3.97261
# [191]	train-rmse:3.88880	test-rmse:3.97261
# [192]	train-rmse:3.88843	test-rmse:3.97257
# [193]	train-rmse:3.88792	test-rmse:3.97247
# [194]	train-rmse:3.88749	test-rmse:3.97224
# [195]	train-rmse:3.88685	test-rmse:3.97193
# [196]	train-rmse:3.88661	test-rmse:3.97188
# [197]	train-rmse:3.88617	test-rmse:3.97224
# [198]	train-rmse:3.88595	test-rmse:3.97257
# [199]	train-rmse:3.88571	test-rmse:3.97248
# ✅ Terminé en 37.69 secondes (soit 0.63 minutes)
# --- RÉSULTATS ---
# Score R² (TEST) : 0.6663
# Score R² (TRAIN) : 0.6821 (Pour vérifier l'overfitting)
# Erreur moyenne (MAE) : 2.64 km/h
# RMSE : 3.97 km/h
# /tmp/ipykernel_20593/1183273223.py:108: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=importances, y=features, palette='viridis')

# %%
# On simule un modèle qui dirait juste : "Demain sera comme hier"
y_pred_naif = X_test['vent_10min_avant']

print(f"Score Naïf R² : {r2_score(y_test, y_pred_naif):.4f}")
print(f"Erreur Naïve (MAE) : {mean_absolute_error(y_test, y_pred_naif):.2f} km/h")
# Out:
# Score Naïf R² : 0.8547
# Erreur Naïve (MAE) : 1.71 km/h
